# %%
# !pip install transformers
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 51.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 31.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 92.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 4.8 MB/s eta 0:00:00
# ...

# %%
from torch import cuda
import transformers

# %%
model_id = 'meta-llama/Llama-2-7b-hf'

# %%
cuda.is_available()
# Out:
# False

# %%
device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
from huggingface_hub import login

access_token_read ="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"

login(token = access_token_read)
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained(
    model_id
)

# %%
generate_text = transformers.pipeline(
    model=model_id,
    tokenizer=tokenizer,
    task="text-generation",
    max_new_tokens=4,
    repetition_penalty=1.1
)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
pre_prompt = "Please attribute the following text to its most appropriate source label from the following options: hep-th, hep-ph, quant-ph, astro-ph, cs.CV. Below are 5 examples of texts with the correct source attributed to them in the format Text: {text} Source: {source}."\
"\nText:tion of unification models as supergravity, superstrings and M-theory [2]. This type of modified gravitation was first introduced in a different context in the 60's in order to incorporate the Mach's\nSource:hep-th"\
"\nText:ra dimensions compactified on a Calabi-Yau threefold and almost all of the compactification moduli including the Calabi-Yau volume stabilized. The advent of KKLT mechanism [1] for moduli stabilization\nSource:hep-th"\
"\nText:heory in arbitrary spacetime is not available yet, it is not possible to construct an exact quantum D-brane model in the most general case. The aim of this letter is to provide a simple method to cons\nSource:hep-th"\
"\nText:astic change of some reaction rates resulting in an overproduction of 6 Li [19]. A number of works [17,[19][20][21][22][23][24][25][26] have studied this effect, typically finding upper bounds of a fe\nSource:hep-ph"\
"\nText:hich is not a constituent of the observed hadron C in the reaction A \u2191 +B \u2192 C + X contributes, with some probability, to the effective color field, which acts on the hadron C quarks. As is shown in [1\nSource:hep-ph"\
"\nText:eckelberg mechanism occur quite naturally D brane constructions where one encounters the group U (N) for a stack of N D branes which is then broken to its subgroup SU (N) via Stueckelberg couplings. T\nSource:hep-ph"\
"\nText:n quantum information and quantum communication [1]. A great deal of attention has been attracted into this field this years, especially the unambiguous discrimination (UD) of quantum stats. UD is a s\nSource:quant-ph"\
"\nText:the framework of the Dirac equation, there exist various possibilities for introducing the oscillator interaction, such as the mixture of the quadratic in coordinate vector and scalar potentials with\nSource:quant-ph"\
"\nText:efect structures to trap light [1], surface polaritons (SPs) to confine light to wavelength dimensions [2] and use nonlinear interactions [3,4], and electromagnetically induced transparency (EIT) to s\nSource:quant-ph"\
"\nText:the MW halo. Recent velocity measurements for several hundred stars per dSph (Kleyna et al. 2002(Kleyna et al. , 2003(Kleyna et al. , 2004;;Mu\u00f1oz et al. 2005Mu\u00f1oz et al. , 2006;;Walker et al. 2006a,b\nSource:astro-ph"\
"\nText:hat are pulsating in two modes simultaneously, also called beat Cepheids) strongly depends on the physical parameters of these stars, namely the mass (M), luminosity (L), mean effective temperature (T \nSource:astro-ph"\
"\nText:nd A-type stars, corresponding to stellar masses ranging from 1.6 M \u2299 to 3.0 M \u2299 . Inspection of the Catalog of Nearby Exoplanets (CNE)1 reveals that only 6 of the 173 stars with securely detected pla\nSource:astro-ph"\
"\nText:ency domain may be considered, usually improving the filtering process. Examples of this situation are found in Electrocardiogram (ECG) and other biomedical signals [20], human voice analysis [22] or\nSource:cs.CV"\
"\nText:ouped into this last mentioned category: heuristic based [6], [7], when the detection is done accordingly to a set of heuristic rules, which aim at describing significant characteristics of human body\nSource:cs.CV"\
"\nText:eoff between precision and recall is critical in this context. In previous research [5]- [7], loop closure detection is typically formulated as a bagof-words image retrieval problem where a query/data\nSource:cs.CV"\
"\nPLEASE ASSIGN THE FOLLOWING TEXT WITH ONE OF THESE FIVE SOURCE LABELS: hep-th, hep-ph, quant-ph, astro-ph, cs.CV\n"

#query_prompt = "\nText: the MW halo. Recent velocity measurements for several hundred stars per dSph (Kleyna et al. 2002(Kleyna et al. , 2003(Kleyna et al. , 2004;;Mu\u00f1oz et al. 2005Mu\u00f1oz et al. , 2006;;Walker et al. 2006a,b\nSource:"

# %%
quant_ph_strings = [
    "n quantum information and quantum communication [1]. A great deal of attention has been attracted into this field this years, especially the unambiguous discrimination (UD) of quantum stats. UD is a s",
    " the framework of the Dirac equation, there exist various possibilities for introducing the oscillator interaction, such as the mixture of the quadratic in coordinate vector and scalar potentials with",
    "efect structures to trap light [1], surface polaritons (SPs) to confine light to wavelength dimensions [2] and use nonlinear interactions [3,4], and electromagnetically induced transparency (EIT) to s",
    "glement [4] is related to the quantum superposition rule of the states of subsystems for a given multipartite system. For pure states, the notion of entanglement and separability can be given as follo",
    "eous emission of atoms [1,2,3,4,5]. The early work of Agarwal on this subject demonstrated trapping of populations in the degenerate excited levels of a V-type atom [1]. For a non-degenerate V system ",
    "ification of multipartite entanglement remains an open problem; a full classification has only been achieved for small numbers of qubits [3,4,5,6,7] and the extension to larger systems represents a fo",
    "lude exploiting photonic crystals with defect structures to trap light [1], surface polaritons (SPs) to confine light to wavelength dimensions [2] and use nonlinear interactions [3,4], and electromagn",
    "national team of six scientists including Charles Bennett [4] discovered a new aspect of quantum inseparability -teleportation. Teleportation is purely based on classical information and non-classical",
    " relevant references can be found in [8,9]). Recently, a new type of incompatibility theorem was introduced by Leggett [8] that allowed for the first time a test of a specific and intuitive class of n",
    "or machines that store and manipulate information. In particular, it appeared that quantum computers might be more powerful than classical computers. This opened up a new direction in computer science",
    "spins will be directed along the magnetic field at t = t tr . Only such quantum processes will be considered in this letter. We say that the quantum state is transfered along the spin chain if it is t",
    "s are the exact mathematical analogs of position and momentum of a quantum harmonic oscillator. In particular, the Bloch-Messiah reduction [2] provides an elegant method for generating any N -partite ",
    "belong. Bob discard the measurement outcomes whose bases do not contain the transmitted qubit. We call such measurement mismatched measurement in this paper. After that, Alice and Bob perform the info",
    "|m using minimum time steps, with the constraints that in one time step we can either examine the current site (i.e. compute f (x, y) for the current site using an oracle query) or move to a neighbori",
    " Tartarus, a dark land of thought where the lightnings of Zeus had never arrived. Since then, and more than one century later, the problem to which quantum mechanics confronts us remains untouched. Th",
    "c vacuum. The scattering formula is developed on adapted plane-waves and multipole basis, leading to an expression valid for arbitrary relative values of the sphere radius and inter-plate distance. In",
    "e of representing at least one qubit. Relevant examples include trapped atoms [1,2,3], and elementary nanostructures such as NV centres within diamond [4,5,6]. Entanglement between structures is to be",
    "h, i.e. there must exist a lower bound to the possible resolution of the distance [1][2][3][4][5][6][7][8]. The minimal length appears due to a modification of the standard Heisenberg uncertainty rela",
    "potential improvements in a variety of applications. Computational advantages [26,14] of quantum computers with many qubits have received the most attention but are difficult to implement physically. ",
    " have the disadvantages of the motional heating of the ions due to their micromotion, and the relatively strong effects of patch potentials formed on the electrodes, particularly with smaller electrod",
    "lications in the quantum information processing such as quantum computing [1], teleportation [2], cryptographic [3], dense coding [4] and entanglement swapping [5]. Entanglement gives new insights for",
    "s assumed. In fact, a lower bound on the min-entropy of the message space is assumed: the most probable message is not too probable. For this reason, this concept is called entropic security in the co",
    "ensional spatial search problem is to find |m using minimum time steps, with the constraints that in one time step we can either examine the current site (i.e. compute f (x, y) for the current site us",
    " spontaneous rotational symmetry breaking that occurs in the transverse plane of some optical systems to produce non-critically squeezed light. In particular, we proved this in the case of a type I De",
    "noise in quantum information processors (QIPs). Optimal control theory minimizes the errors caused by uncertainty in the system Hamiltonian [5,6]. Dynamical decoupling and bang-bang control actively s",
    "e history of thought (Blaise Pascal 1654) and it evolved slowly (Bernoulli 1713, Richard von Mises 1931). The first thorough axiomatic and mathematical formalisation has been given by Andre\u00ef N. Kolmog",
    "93 an international team of six scientists including Charles Bennett [4] discovered a new aspect of quantum inseparability -teleportation. Teleportation is purely based on classical information and no",
    "n of entanglement is the key ingredient of quantum information processing. In optical implementation with discrete variables the standard source of entangled photon pairs is parametric down-conversion",
    "cally decodable codes (LDCs) have received much attention in the last decade. They are errorcorrecting codes that encode n bits into m bits, with the usual error-correcting properties, and the additio",
    "ough the precise way in which general relativity would alter quantum mechanics on these scales is not known theoretically, and proves to be extremely hard to access experimentally [3,4,5], Penrose and",
    "+ ab \u2020 , G = a \u2020 b \u2020 + ab, or G = a \u20202 + a 2 , [a, a \u2020 ] = 1 and [b, b \u2020 ] = 1 being mode operators. We are interested in evaluating the ultimate bound on precision (sensitivity), i.e the smallest val",
    "sponse of the individual molecules. Processes where the detected signal is obtained by simply adding up the contributions of the individual particles in the sample, are termed incoherent. Such signals",
    " matrix. For high dimensions, where the matrices become large (for composite systems of n particles the matrices are of even much larger dimension d n \u00d7 d n ), a simple way to express density matrices",
    "ale arms. However, to reach such high sensitivities, optical cavities play an essential role. Arm cavities and power recycling cavities which are tuned to resonance for the laser carrier light, are us",
    "Z) states which would be totally disentangled, cluster states can still maintain some entanglement [1]. A recent theoretical paper [2] shows that cluster states can be used to construct a GHZ-type arg",
    "meindependent or slowly varying classical probability distribution of Hamiltonians. Evolution under such a process is naturally described as an operator sum, given in superoperator notation [3,4] by \u015c",
    "d by the same vacuum modes to other levels. Many remarkable features have been predicted employing the mechanism of interferences in the spontaneous emission of atoms [1,2,3,4,5]. The early work of Ag",
    "imitation, as is well known, is that quantum systems are highly sensitive to the influence of the surrounding environment which tends to destroy quantum coherence: it becomes important to analyze to w",
    "ravity models claim for possible violations of the equivalence principle of General Relativity in antimatter [2]. Testing the validity of this principle is an important issue, and may involve measurem",
    "on about s. The condition \"without revealing any information\" has been formalized in [GMR89,GMW91] and this security condition has been defined in the computational (CZK) and the information-theoretic",
    "positive. Hence, if two or more observables have no eigenstates in common, the sum of these respective entropies is strictly greater than 0 for any state we may measure. We thereby say that a set of o",
    " V that he knows s without revealing any information about s. The condition \"without revealing any information\" has been formalized in [GMR89,GMW91] and this security condition has been defined in the",
    " = nT , given by the product of the number of subsystems and the interaction time T . The standard quantum limit (SQL) precision in the estimation of an interaction parameter is of order O(1/ \u221a N ), a",
    "al modes of the system [1]; the longitudinal bulk modes can be used to find, e.g., the polaron energy in a polar semiconductor or the exchangecorrelation energy in a metal; the transverse modes to fin",
    "mance is, however, still far from practical use. The secure key rate for BB84 over 100 km remains around 10 bps [9,10]. Although a higher key rate about 17 kbps was marked over 100 km with differentia",
    "r, Bob, measures the received qubits with either {|0 , |1 } or {|+ , |-} basis. After that, Alice publicly announces to which {|0 , |1 } or {|+ , |-} basis each qubit belong. Bob discard the measureme",
    "lement in massive particles as in photons. With recent advances in cavity QED technologies, cavity-QED-based schemes are an attractive candidate for generation of entanglement between atoms or ions. T",
    " to the memory device, but this information is not necessarily available when reading from it. What is the best asymptotic rate at which we can store qubits reliably on this device? This problem can b",
    "tum observables such as the amplitude and phase quadratures of the electromagnetic field. Entanglement between these variables is then analogous to the position and momentum of the original EPR Gedank",
    "um computation processes such as quantum cryptography, teleportation, dense coding and quantum key distribution [1,2,3] which cannot be realized in classical physics. So a strong motivation has been r"
]

# %%
'''

from transformers import AutoTokenizer, LlamaForCausalLM
import transformers
import torch

mn = "meta-llama/Llama-2-7b-hf"
model = LlamaForCausalLM.from_pretrained(mn)

tokenizer = AutoTokenizer.from_pretrained(mn)

special_tokens_dict = {'mask_token': '<mask>'}

num_added_toks = tokenizer.add_special_tokens(special_tokens_dict)

model.resize_token_embeddings(len(tokenizer))

pipeline = transformers.pipeline(
    "fill-mask",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.float16,
    device_map="auto",
)

seq = pipeline(
    t_prompt,
    top_k=2,
)

for s in seq:
  ans = s['token_str']
  ans2 = s['sequence']
  print(ans2)
'''
# Out:
# '\n\nfrom transformers import AutoTokenizer, LlamaForCausalLM\nimport transformers\nimport torch\n\nmn = "meta-llama/Llama-2-7b-hf"\nmodel = LlamaForCausalLM.from_pretrained(mn)\n\ntokenizer = AutoTokenizer.from_pretrained(mn)\n\nspecial_tokens_dict = {\'mask_token\': \'<mask>\'}\n\nnum_added_toks = tokenizer.add_special_tokens(special_tokens_dict)\n\nmodel.resize_token_embeddings(len(tokenizer))\n\npipeline = transformers.pipeline(\n    "fill-mask",\n    model=model,\n    tokenizer=tokenizer,\n    torch_dtype=torch.float16,\n    device_map="auto",\n)\n\nseq = pipeline(\n    t_prompt,\n    top_k=2,\n)\n\nfor s in seq:\n  ans = s[\'token_str\']\n  ans2 = s[\'sequence\']\n  print(ans2)\n'

# %%
correct = 0
count = 0
for s in quant_ph_strings:
  print("iteration", count)
  query_prompt = f"\nText:{s}\nSource:"
  print("query_prompt: ", query_prompt)
  print("running iteration:", count, "inference...")
  res = generate_text(
      pre_prompt + query_prompt,
      top_k=1
  )
  print("finish iteration:", count, "inference")

  text = res[0]["generated_text"]
  print("-----------------------")
  print("generated_text: ", text)
  print("-----------------------")
  index = text.rfind(":")
  label = text[index+1:index+10].strip()
  print(label)
  if (label == "quant-ph"):
    correct += 1
    print("correct: ", correct)
  count += 1
  print("count: ", count)
  print("\n=======================================================\n")

print(correct/count)
# Out:
# iteration 0
# query_prompt:
# Text:n quantum information and quantum communication [1]. A great deal of attention has been attracted into this field this years, especially the unambiguous discrimination (UD) of quantum stats. UD is a s
# Source:
# running iteration: 0 inference...
# finish iteration: 0 inference
# -----------------------
# generated_text:  Please attribute the following text to its most appropriate source label from the following options: hep-th, hep-ph, quant-ph, astro-ph, cs.CV. Below are 5 examples of texts with the correct source attributed to them in the format Text: {text} Source: {source}.
# Text:tion of unification models as supergravity, superstrings and M-theory [2]. This type of modified gravitation was first introduced in a different context in the 60's in order to incorporate the Mach's
# Source:hep-th
# ...
