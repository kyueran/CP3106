# %%
# !pip install transformers
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 50.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 29.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 92.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 4.3 MB/s eta 0:00:00
# ...

# %%
from torch import cuda
import transformers

# %%
model_id = 'meta-llama/Llama-2-7b-hf'

# %%
cuda.is_available()
# Out:
# False

# %%
device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
from huggingface_hub import login

access_token_read ="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"

login(token = access_token_read)
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained(
    model_id
)

# %%
generate_text = transformers.pipeline(
    model=model_id,
    tokenizer=tokenizer,
    task="text-generation",
    max_new_tokens=4,
    repetition_penalty=1.1
)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
pre_prompt = "Please attribute the following text to its most appropriate source label from the following options: hep-th, hep-ph, quant-ph, astro-ph, cs.CV. Below are 5 examples of texts with the correct source attributed to them in the format Text: {text} Source: {source}."\
"\nText:tion of unification models as supergravity, superstrings and M-theory [2]. This type of modified gravitation was first introduced in a different context in the 60's in order to incorporate the Mach's\nSource:hep-th"\
"\nText:ra dimensions compactified on a Calabi-Yau threefold and almost all of the compactification moduli including the Calabi-Yau volume stabilized. The advent of KKLT mechanism [1] for moduli stabilization\nSource:hep-th"\
"\nText:heory in arbitrary spacetime is not available yet, it is not possible to construct an exact quantum D-brane model in the most general case. The aim of this letter is to provide a simple method to cons\nSource:hep-th"\
"\nText:astic change of some reaction rates resulting in an overproduction of 6 Li [19]. A number of works [17,[19][20][21][22][23][24][25][26] have studied this effect, typically finding upper bounds of a fe\nSource:hep-ph"\
"\nText:hich is not a constituent of the observed hadron C in the reaction A \u2191 +B \u2192 C + X contributes, with some probability, to the effective color field, which acts on the hadron C quarks. As is shown in [1\nSource:hep-ph"\
"\nText:eckelberg mechanism occur quite naturally D brane constructions where one encounters the group U (N) for a stack of N D branes which is then broken to its subgroup SU (N) via Stueckelberg couplings. T\nSource:hep-ph"\
"\nText:n quantum information and quantum communication [1]. A great deal of attention has been attracted into this field this years, especially the unambiguous discrimination (UD) of quantum stats. UD is a s\nSource:quant-ph"\
"\nText:the framework of the Dirac equation, there exist various possibilities for introducing the oscillator interaction, such as the mixture of the quadratic in coordinate vector and scalar potentials with\nSource:quant-ph"\
"\nText:efect structures to trap light [1], surface polaritons (SPs) to confine light to wavelength dimensions [2] and use nonlinear interactions [3,4], and electromagnetically induced transparency (EIT) to s\nSource:quant-ph"\
"\nText:the MW halo. Recent velocity measurements for several hundred stars per dSph (Kleyna et al. 2002(Kleyna et al. , 2003(Kleyna et al. , 2004;;Mu\u00f1oz et al. 2005Mu\u00f1oz et al. , 2006;;Walker et al. 2006a,b\nSource:astro-ph"\
"\nText:hat are pulsating in two modes simultaneously, also called beat Cepheids) strongly depends on the physical parameters of these stars, namely the mass (M), luminosity (L), mean effective temperature (T \nSource:astro-ph"\
"\nText:nd A-type stars, corresponding to stellar masses ranging from 1.6 M \u2299 to 3.0 M \u2299 . Inspection of the Catalog of Nearby Exoplanets (CNE)1 reveals that only 6 of the 173 stars with securely detected pla\nSource:astro-ph"\
"\nText:ency domain may be considered, usually improving the filtering process. Examples of this situation are found in Electrocardiogram (ECG) and other biomedical signals [20], human voice analysis [22] or\nSource:cs.CV"\
"\nText:ouped into this last mentioned category: heuristic based [6], [7], when the detection is done accordingly to a set of heuristic rules, which aim at describing significant characteristics of human body\nSource:cs.CV"\
"\nText:eoff between precision and recall is critical in this context. In previous research [5]- [7], loop closure detection is typically formulated as a bagof-words image retrieval problem where a query/data\nSource:cs.CV"\
"\nPLEASE ASSIGN THE FOLLOWING TEXT WITH ONE OF THESE FIVE SOURCE LABELS: hep-th, hep-ph, quant-ph, astro-ph, cs.CV\n"

#query_prompt = "\nText: the MW halo. Recent velocity measurements for several hundred stars per dSph (Kleyna et al. 2002(Kleyna et al. , 2003(Kleyna et al. , 2004;;Mu\u00f1oz et al. 2005Mu\u00f1oz et al. , 2006;;Walker et al. 2006a,b\nSource:"

# %%
hep_ph_strings = [
    "astic change of some reaction rates resulting in an overproduction of 6 Li [19]. A number of works [17,[19][20][21][22][23][24][25][26] have studied this effect, typically finding upper bounds of a fe",
    "hich is not a constituent of the observed hadron C in the reaction A \u2191 +B \u2192 C + X contributes, with some probability, to the effective color field, which acts on the hadron C quarks. As is shown in [1",
    "eckelberg mechanism occur quite naturally D brane constructions where one encounters the group U (N) for a stack of N D branes which is then broken to its subgroup SU (N) via Stueckelberg couplings. T",
    "ue of particular interest being that of the regularity of the boundaries of the resulting jets. This is related to the question of their sensitivity to non-perturbative effects like hadronisation and ",
    "ther [3,4,5,6,7,8,9]. Many theories or models have been proposed to extend the standard model of electroweak interaction. One of the interesting model is the left-right symmetry model based on the SU ",
    "sons. Radiative corrections to scattering processes depend on the ratio of mass scales, and radiative corrections at high energy depend on logarithms of the form log s/M 2 W,Z . In high energy exclusi",
    " V \u2020 d , where the unitary matrices V u and V d diagonalize the up-quark and down-quark Dirac mass matrices M u and M d , respectively. Given this circumstance, complete knowledge of the mass matrices",
    "a packages for the generation and calculation of Feynman diagrams up to one-loop order. This contribution describes a new tool for graphically editing Feynman diagrams in FeynArts' L A T E X format as",
    "is determined by the so-called dimensional transmutation. However the fundamental scalar theory necessarily allows a relevant operator, the scalar mass term, which causes the gauge hierarchy problem. ",
    "scillation data from Super-Kamiokande has provided a solid evidence that neutrinos have small but non-zero masses. The global fit to current data from neutrino oscillation experiments give the followi",
    "ame in particular the hierarchy problem or dark matter/energy problems. As an attempt to solve these problems, supersymmetry (SUSY) appears as a highly motivated and studied model during the past deca",
    "field theories and string theories studied. Even so, I will argue that unitarity may be the key to the origin of the Standard Model as a bound-state S-Matrix embedded (without off-shell amplitudes) in",
    "ratio is a measure of the number of particles produced in a proton-nucleus collision versus the number of particles in proton-proton collisions times the number of collisions. The transverse momentum ",
    " the upcoming experiments at the CERN Large Hadron Collider (LHC) is the determination of the mechanisms of electroweak symmetry breaking and of the generation of elementary particle masses. In the Mi",
    "t lowest order there are no free parameters apart from masses and f \u03c0 , the pion decay constant, that sets the scale \u039b \u2261 4\u03c0f \u03c0 . The chiral expansion can be renormalized order by order by absorbing th",
    "ry (SUSY) exists at or around the TeV energy scale, experiments at the LHC have excellent prospects to discover it [1,2]. The discovery of SUSY particles will be followed by detailed measurements [3,4",
    "1,2] have been converted into a strong evidence in the last 10 years [3,4,5,6,7,8,9,10]: the only consistent explanation for solar neutrino data, atmospheric neutrino data, reactor and accelerator neu",
    "f course a lot more work done within ChPT relevant for Kaon decays than I can possibly do justice to within this short talk. Other theory talks with a very large ChPT content presented at this confere",
    "xed point (examples being afforded by a vector-like non-abelian gauge theory with a large number of massless fermions as studied by Banks and Zaks (BZ) [3], or certain nonlinear sigma models [4]). Man",
    " nature of the CDM is one of the biggest puzzles in theoretical particle physics today. Since all known particles are ruled out as dark matter candidates, the dark matter problem provides one of the s",
    "of a H\u00fcckel-Debye color screening is often proposed as a signal of the presence of a QCD plasma. It is a property of the electric plasma which is frequently transported to the QCD plasma. In the elect",
    "nt degrees of freedom are t-channel \"Reggeized\" gluons which interact with each other via standard gluons in the s-channel and a gauge invariant Reggeized gluon -Reggeized gluon -gluon vertex. This pi",
    "ssary to dynamically generate a baryon asymmetry in an initially baryon-symmetric universe: (1) baryon number non-conserving interactions; (2) C and CP violation; (3) departure from thermal equilibriu",
    "MeV, i.e. of the order of the electromagnetic and of the u -d quark mass differences. Indications of a mass difference between the X state decaying in J/\u03c8\u03c0 + \u03c0 - [2] and the one decaying in D 0 D0 \u03c0 0",
    "mproved precisions [1], and the Particle Data Group quote BR(\u03c6 \u2192 \u03c9\u03c0 0 ) = (5.2 +1. 3  -1.1 ) \u00d7 10 -5 as the world average for its branching ratio [2]. This decay channel is very interesting due to the",
    " c/m \u03c6 0.1 mm if the field is to couple to matter with a strength equal to that of gravity. The bounds on fields whose interactions with matter have a super-gravitational strength are even tighter [1]",
    ", we re-visit the results in Refs. [2] from the standpoint of recent progress [4,5] in the resummation of large IR effects in the QCD perturbation theory, where we will focus on exact resummation meth",
    " consideration, such an asymmetry can arise from spin and transverse momentum dependent fragmentation functions, which in turn can arise from two types of interactions. We will point out how the measu",
    "cy \u2206m Bs and the first bounds on the mixing phase -2\u03b2 s , until the very recent evidence of D 0 -D0 mixing, \u2206F = 2 processes have always provided some of the most stringent constraints on New Physics ",
    "ises solely from the phase in the 3 \u00d7 3 unitary CKM matrix and any CP violating observable is proportional to Im(V ij V * il V * kj V kl ), with i = k and j = l. The SU(3) invariant amplitude for B \u2192 ",
    "uential family and in this way complete the flavor structure of the theory. The joining of these two issues, the flavor problem and electroweak symmetry breaking, is a prime motivation to consider the",
    "h the minimal supersymmetrization of the SM requires one super-partner for each SM particle (and two Higgs doublets), it is very constrained and involves only a few free parameters. The problem, howev",
    "is the next-to-next-to leading (NNLO) order [1], due to the availability of a variety of novel computational techniques. Results for cross-sections at NNLO can be used thanks to the recent determinati",
    "ing we will outline some recent developments in devising a renormalization scheme leading to a simple and consistent power counting for manifestly Lorentz-invariant baryon ChPT [4]. The approach allow",
    "ring to resolve the quark and gluon content in the Pomeron. 2 Observations of diffractive deep inelastic scattering at HERA have increased the knowledge about the QCD Pomeron, providing us with the di",
    "lor screening is often proposed as a signal of the presence of a QCD plasma. It is a property of the electric plasma which is frequently transported to the QCD plasma. In the electric case, with inter",
    ": why is there a mixing angle hierarchy in the quark sector but not in the lepton sector? Usually mass matrices have the form M \u03b1\u03b2 = i (\u0393 i ) \u03b1\u03b2 \u03a6 0 i , where the \u0393 i 's are, for Dirac fermions, arbit",
    "blem in hadron physics. Over the last three decades many theories have been suggested to elucidate this phenomenon. It has turned out that the main challenge for such theories is posed by the properti",
    "xists as a result of the electroweak symmetry breaking (EWSB), of which mass is not predicted in the theoretical framework. The discovery potential for the SM Higgs boson at the LHC will reach to abou",
    "gnal in this mode has been found and in a 90% confident level the upper limit of the branching ratio is about 1.6 \u00d7 10 -5 . The previous CLEO search of \u03a5(1s) \u2192 \u03b3\u03b7 produced an upper limit of 2.1 \u00d7 10 -",
    "plications the predictivity of \u03c7pt depends on realistic estimates of these lecs. An up-todate account of our knowledge about the lecs can be found in the recent conference reports of Ecker [\uf734] and Bij",
    "In astronomy, GRB's are detected once a day on average. If an accelerated proton produces a pion, about 20% of its energy is transferred to neutrinos, although more than one pion can be produced from ",
    " the observable sector, and the effect of SUSY breaking must be communicated to the observable sector by some mediation mechanism. There are many proposed SUSY breaking and mediation mechanisms, such ",
    "he top-quark which disagrees with the results of experimental measurements obtained at FNAL. This problem can be overcome within supersymmetric (SUSY) and nonsupersymmetric two Higgs doublet extension",
    "ere are strong hints that the Standard Model (SM) is only an effective theory valid up to the TeV range, and new physics is needed to explain particle dynamics (much) beyond this energy scale. Among m",
    "on. Here, we study this problem quantitatively and provide details about how the deuteron would respond to variations in its potential induced by changes in m u + m d [2]. The deuteron is an example o",
    "articles [1,2]. The unparticle weakly couples to the Standard Model(SM) matter, which is suppressed by the inverse of large energy scale from the view of the effective theory. This scenario serves as ",
    " quarks. It was recognized that the reconciliation between the bag model and the heavy quark physics could be achieved by taking into account the so-called c.m.m. (center of mass motion) correction. F",
    "n many experiments. Its perturbative regime will be crucial at the imminent high-energy proton-proton collider LHC. The main target of LHC, is to find signals of the Standard Model Higgs boson and of ",
    "ertex and k 2 T , for the jet vertex. In this short report, we will only discuss the phenomelogical aspects and all detailed calculations can be found in Ref. [5] for forward jets at HERA and in Ref. "
]

# %%
'''

from transformers import AutoTokenizer, LlamaForCausalLM
import transformers
import torch

mn = "meta-llama/Llama-2-7b-hf"
model = LlamaForCausalLM.from_pretrained(mn)

tokenizer = AutoTokenizer.from_pretrained(mn)

special_tokens_dict = {'mask_token': '<mask>'}

num_added_toks = tokenizer.add_special_tokens(special_tokens_dict)

model.resize_token_embeddings(len(tokenizer))

pipeline = transformers.pipeline(
    "fill-mask",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.float16,
    device_map="auto",
)

seq = pipeline(
    t_prompt,
    top_k=2,
)

for s in seq:
  ans = s['token_str']
  ans2 = s['sequence']
  print(ans2)
'''
# Out:
# '\n\nfrom transformers import AutoTokenizer, LlamaForCausalLM\nimport transformers\nimport torch\n\nmn = "meta-llama/Llama-2-7b-hf"\nmodel = LlamaForCausalLM.from_pretrained(mn)\n\ntokenizer = AutoTokenizer.from_pretrained(mn)\n\nspecial_tokens_dict = {\'mask_token\': \'<mask>\'}\n\nnum_added_toks = tokenizer.add_special_tokens(special_tokens_dict)\n\nmodel.resize_token_embeddings(len(tokenizer))\n\npipeline = transformers.pipeline(\n    "fill-mask",\n    model=model,\n    tokenizer=tokenizer,\n    torch_dtype=torch.float16,\n    device_map="auto",\n)\n\nseq = pipeline(\n    t_prompt,\n    top_k=2,\n)\n\nfor s in seq:\n  ans = s[\'token_str\']\n  ans2 = s[\'sequence\']\n  print(ans2)\n'

# %%
correct = 0
count = 0
for s in hep_ph_strings:
  print("iteration", count)
  query_prompt = f"\nText:{s}\nSource:"
  print("query_prompt: ", query_prompt)
  print("running iteration:", count, "inference...")
  res = generate_text(
      pre_prompt + query_prompt,
      top_k=1
  )
  print("finish iteration:", count, "inference")

  text = res[0]["generated_text"]
  print("-----------------------")
  print("generated_text: ", text)
  print("-----------------------")
  index = text.rfind(":")
  label = text[index+1:index+10].strip()
  print(label)
  if (label == "hep-ph"):
    correct += 1
    print("correct: ", correct)
  count += 1
  print("count: ", count)
  print("\n=======================================================\n")

print(correct/count)
# Out:
# iteration 0
# query_prompt:
# Text:astic change of some reaction rates resulting in an overproduction of 6 Li [19]. A number of works [17,[19][20][21][22][23][24][25][26] have studied this effect, typically finding upper bounds of a fe
# Source:
# running iteration: 0 inference...
# finish iteration: 0 inference
# -----------------------
# generated_text:  Please attribute the following text to its most appropriate source label from the following options: hep-th, hep-ph, quant-ph, astro-ph, cs.CV. Below are 5 examples of texts with the correct source attributed to them in the format Text: {text} Source: {source}.
# Text:tion of unification models as supergravity, superstrings and M-theory [2]. This type of modified gravitation was first introduced in a different context in the 60's in order to incorporate the Mach's
# Source:hep-th
# ...
